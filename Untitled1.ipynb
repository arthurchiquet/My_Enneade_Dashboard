# %%
from pangres import upsert
import pandas as pd
from data import memoized_data
from utils_topo import format_df, extract_3d_positions

# %%
df=memoized_data('chantier_1', 'actif', 'topographie.csv')

# %%
def manu_auto(cible):
    return cible[:4].lower()

# %%
df = extract_3d_positions(df, ['Auto-AC11a', 'Auto-AC311a', 'Auto-AC32a', 'Auto-AC7Ba', 'Manu-VJ5', 'Manu-VB2'], 'AB')
# Out:
# ---------------------------------------------------------------------------
# InvalidResponse                           Traceback (most recent call last)
# ~/.pyenv/versions/3.8.5/envs/lewagon/lib/python3.8/site-packages/google/cloud/storage/blob.py in download_to_file(self, file_obj, client, start, end, raw_download, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum)
#    1040         try:
# -> 1041             self._do_download(
#    1042                 transport,
#
# ~/.pyenv/versions/3.8.5/envs/lewagon/lib/python3.8/site-packages/google/cloud/storage/blob.py in _do_download(self, transport, file_obj, download_url, headers, start, end, raw_download, timeout, checksum)
#     899             )
# --> 900             response = download.consume(transport, timeout=timeout)
#     901             self._extract_headers_from_download(response)
#
# ...

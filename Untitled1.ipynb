# %%
from data import query_data
import pandas as pd
import numpy as np
import plotly.express as px

chantier='chantier_1'

coeff_Lamb_GPS = [[1.23952112e-05, 6.63800392e-07], [-4.81267332e-07,  8.98816386e-06]]
intercept_Lamb_GPS = [-20.17412175, 16.14120241]

def changement_repere(df, coef, intercept):
    lon = df.x * coef[0][0] + df.y * coef[0][1] + intercept[0]
    lat = df.x * coef[1][0] + df.y * coef[1][1] + intercept[1]
    df.x, df.y = lat, lon
    return df

def remove_xyz(string):
    return string.replace('.x','').replace('.y', '')

def first(col):
    i = 0
    for j in col:
        if (not np.isnan(j)) & (i == 0):
            i = j
            break
    return i

# %%
df = query_data(chantier, 'actif', 'topographie.csv', sep=False).drop(columns=['date'])

# %%
df = pd.DataFrame(df.apply(first)).T

# %%
dfx = df[[col for col in df.columns if '.x' in col]].stack().reset_index().drop(columns=['level_0']).rename(columns={'level_1':'cible',0:'x'})
dfy = df[[col for col in df.columns if '.y' in col]].stack().reset_index().drop(columns=['level_0']).rename(columns={'level_1':'cible',0:'y'})

# %%
dfx.cible = dfx.cible.map(remove_xyz)
dfy.cible = dfy.cible.map(remove_xyz)

# %%
df2 = dfx.merge(dfy)

# %%
df2 = changement_repere(df2, coeff_Lamb_GPS, intercept_Lamb_GPS)

# %%
fig = px.scatter_mapbox(
    df2,
    lat="x",
    lon="y",
    text='cible'
)

# %%
mapbox_token = 'pk.eyJ1IjoiYXJ0aHVyY2hpcXVldCIsImEiOiJja2E1bDc3cjYwMTh5M2V0ZzdvbmF5NXB5In0.ETylJ3ztuDA-S3tQmNGpPQ'

# %%
fig.update_layout(
    mapbox_style="dark",
    mapbox_accesstoken=mapbox_token,
    plot_bgcolor=colors['background'],
    paper_bgcolor=colors['background'],
    font_color=colors['text'],
)

# %%
import plotly.graph_objects as go
from config import engine
import pandas as pd
import plotly.express as px

# %%
chantier='chantier_1'

# %%
fig = go.Figure()

# %%
with engine.connect() as con:
    query="select * from capteur where chantier ='%s'"%chantier
    df = pd.read_sql_query(query, con=con)

# %%
coeff_Lamb_GPS = [[1.23952112e-05, 6.63800392e-07], [-4.81267332e-07,  8.98816386e-06]]
intercept_Lamb_GPS = [-20.17412175, 16.14120241]

def changement_repere(df, coef, intercept):
    lon = df.lat * coef[0][0] + df.lon * coef[0][1] + intercept[0]
    lat = df.lat * coef[1][0] + df.lon * coef[1][1] + intercept[1]
    df.lat, df.lon = lat, lon
    return df

df = changement_repere(df, coeff_Lamb_GPS, intercept_Lamb_GPS)

# %%
mapbox_token = 'pk.eyJ1IjoiYXJ0aHVyY2hpcXVldCIsImEiOiJja2E1bDc3cjYwMTh5M2V0ZzdvbmF5NXB5In0.ETylJ3ztuDA-S3tQmNGpPQ'

colors = {
    'background': '#222222',
    'text': 'white'
}

fig.add_trace(go.Scattermapbox(
        name='Cible',
        lat=df[df.type=='cible'].lat,
        lon=df[df.type=='cible'].lon,
        text=df[df.type=='cible'].capteur,
    ))

fig.add_trace(go.Scattermapbox(
        name='Inclinometre',
        lat=df[df.type=='inclino'].lat,
        lon=df[df.type=='inclino'].lon,
        text=df[df.type=='inclino'].capteur,
    ))

fig.update_layout(
    mapbox_style="dark",
    mapbox_accesstoken=mapbox_token
)
fig.update_layout(
    plot_bgcolor=colors['background'],
    paper_bgcolor=colors['background'],
    font_color=colors['text'],
    legend=dict(
        yanchor="top",
        y=0.99,
        xanchor="left",
        x=0.01
    ),
    legend_title_text=None,
)
fig.update_traces(
    hovertemplate='%{text}',
    textfont_size=11)
# Out:
# <div>                            <div id="cfe030bd-eccb-4b9d-b0b5-2726c12e40aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cfe030bd-eccb-4b9d-b0b5-2726c12e40aa")) {                    Plotly.newPlot(                        "cfe030bd-eccb-4b9d-b0b5-2726c12e40aa",                        [{"hovertemplate": "%{text}", "lat": [43.73157588238377, 43.7317144837831, 43.731714604099935, 43.73185694974014, 43.73185694974014, 43.731881667190756, 43.731887927046316, 43.73174056369774, 43.73174056369774, 43.731935153885445, 43.731935153885445, 43.731852193844986, 43.731852193844986, 43.73182214009462, 43.731820398880785, 43.731590777111265, 43.73159200145915, 43.73160566756044, 43.731604705025774, 43.73158821485916, 43.73158713200766, 43.73157330999092, 43.73157441402198, 43.73159236240964, 43.73159669381563, 43.73157181368907, 43.731591095702655, 43.731945818826404, 43.73195309461455, 43.731959113836446, 43.731959917075415, 43.7319509322918, 43.731652730825544, 43.73165497786651, 43.731950005355756, 43.73158451297738, 43.73194994519734, 43.73159017124878, 43.73154741393178, 43.731936108761545, 43.73194298800058, 43.73194429030619, 43.73189925372986, 43.73193077246178, 43.731826506201145, 43.73166393719225, 43.731582039721815, 43.73153284545425, 43.7316395637909, 43.731578415797756, 43.731605062596024, 43.73161517597049, 43.73159575922102, 43.73158394361158, 43.73137311065142, 43.73147478333965, 43.73159575922102, 43.73160145647128, 43.731595819379436, 43.73160145647128, 43.73159575922102, 43.73160542692677, 43.731612748454275, 43.731604761803936, 43.731610681888554, 43.731613873664884, 43.731595819379436, 43.73158394361158, 43.73156982080277, 43.7315699411196, 43.73158169657062, 43.731595819379436, 43.73161381350646, 43.731615055653656, 43.731570061436436, 43.73159575922102, 43.7316533934662, 43.7316486587506, 43.73164693533609, 43.73164244125415, 43.73163865127391, 43.73163427750882, 43.73163855551688, 43.731636128000666, 43.73163231346062, 43.731625331704066, 43.73164597190335, 43.73166393719225, 43.73146900385335, 43.731280324507594, 43.73127912133927, 43.73127641421053, 43.73127527120061, 43.73127043734773, 43.73126941465465, 43.731269135042126, 43.73127011875634, 43.73126971882698, 43.73126863597548, 43.73159669381563, 43.73157181368907, 43.731530124804515, 43.731528178555635, 43.73125688728496, 43.7312570076018, 43.73125919448434, 43.73125931480118, 43.73124727973763, 43.73124727973763, 43.73124727973763, 43.73124733989604, 43.73123434229783, 43.73123434229783, 43.73123440245625, 43.73123434229783, 43.73124720516015, 43.73124720516015, 43.73124720516015, 43.73129742550104, 43.73129748565946, 43.73126517134713, 43.73126505103029, 43.73126505103029, 43.73127375620138, 43.73127363588455, 43.73127363588455, 43.73127666498493, 43.73160773074591, 43.73131641776135, 43.731314673167276, 43.731605062596024, 43.73161517597049, 43.73129082677261, 43.7312420883145, 43.73159250052579, 43.731583611499204, 43.73160494227919, 43.73148654644924, 43.731555903927074, 43.73156872443028, 43.73158228801404, 43.73149092021434, 43.73155584376866, 43.73148429940828, 43.73148157109998, 43.7316533934662, 43.7316486587506, 43.73164693533609, 43.73164244125415, 43.73163865127391, 43.73163415719198, 43.73165644036589, 43.73124788132179, 43.73126240405997, 43.731360832472035, 43.73144708342609, 43.731511585871495, 43.73144495670196, 43.73150490490701, 43.73123670965563, 43.731344086354625, 43.73128692075385, 43.73138693356623, 43.73129372203516, 43.73138225900905, 43.73127436206387, 43.73127532797878, 43.73127330377217, 43.73126897236618, 43.73126727013121, 43.73126692698003, 43.73127701241444, 43.731275246640806, 43.731447578214414, 43.73151873278617, 43.731545177031556, 43.73154062279121, 43.73154523718998, 43.73154074310 ...
